# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import AutoModel, AutoTokenizer
from transformers import AdamW, get_scheduler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd
# Out:
# C:\Users\amil\anaconda3\envs\tf_gpu\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\amil\anaconda3\envs\tf_gpu\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
# C:\Users\amil\anaconda3\envs\tf_gpu\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df = pd.read_csv(r"C:\Users\amil\OneDrive\Documents\AI-Driven Personalized Therapy Recommendations system\Module_3\Predictive_model\data_set\processed_data\preprocessed_data1.csv")

# %%
df
# Out:
#                                                      text  \
# 0       stress and anxiety are common issues that peop...
# 1       i am living in your walls i am living in your ...
# 2       how helpful have they been for you if youve ta...
# 3       i guess im just not good enough for anyone fuc...
# 4       i am struggling with the outcome of a court ma...
# ...                                                   ...
# 141995  i cannot suffer from an anxiety disorder when ...
# 141996  a question of mine about a question of mine th...
# 141997  welcome to this months personal accountability...
# 141998  agree that you should stop smoking weed usuall...
# 141999  catherine the duchess of cambridge doesnt look...
#
#                        label
# 0                     stress
# 1              mentalillness
# 2       personality disorder
# 3                 depression
# 4                        bpd
# ...                      ...
# 141995        panic_disorder
# 141996            offmychest
# 141997     hoarding disorder
# 141998        social anxiety
# 141999       eating disorder
#
# [142000 rows x 2 columns]

# %%
df['label'].unique()
# Out:
# array(['stress', 'mentalillness', 'personality disorder', 'depression',
#        'bpd', 'ocd', 'normal', 'ptsd', 'anxiety', 'bipolar',
#        'schizophrenia', 'suicidal', 'bdd', 'social anxiety',
#        'hoarding disorder', 'adhd', 'panic_disorder', 'offmychest',
#        'eating disorder'], dtype=object)

# %%
df['label'].value_counts()
# Out:
# label
# suicidal                7496
# depression              7468
# anxiety                 7446
# offmychest              7440
# normal                  7417
# bipolar                 7377
# ptsd                    7351
# adhd                    7286
# mentalillness           7277
# bpd                     7259
# schizophrenia           7196
# bdd                     6540
# panic_disorder          6371
# eating disorder         6227
# ocd                     6124
# personality disorder    6074
# hoarding disorder       5923
# stress                  4672
# social anxiety          4438
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace = True)

# %%
df['label'].unique()
# Out:
# array(['stress', 'mentalillness', 'personality disorder', 'depression',
#        'bpd', 'ocd', 'normal', 'ptsd', 'anxiety', 'bipolar',
#        'schizophrenia', 'suicidal', 'bdd', 'social anxiety',
#        'hoarding disorder', 'adhd', 'panic_disorder', 'offmychest',
#        'eating disorder'], dtype=object)

# %%
import pandas as pd

categories = ['stress', 'mentalillness', 'personality disorder', 'depression',
       'bpd', 'ocd', 'normal', 'ptsd', 'anxiety', 'bipolar',
       'schizophrenia', 'suicidal', 'bdd', 'social anxiety',
       'hoarding disorder', 'adhd', 'panic_disorder', 'offmychest',
       'eating disorder']
target_size = 6000  # Maximum allowed samples per class
balanced_df_list = []

for category in categories:
    category_df = df[df['label'] == category]
    balanced_df_list.append(category_df.sample(n=min(len(category_df), target_size), random_state=42).reset_index(drop=True))

df = pd.concat(balanced_df_list).reset_index(drop=True)

# Shuffle the dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
label_encoder = LabelEncoder()
df["encoded_labels"] = label_encoder.fit_transform(df["label"])  
df
# Out:
#                                                      text  \
# 0       stress and anxiety are common issues that peop...
# 1       i am living in your walls i am living in your ...
# 2       how helpful have they been for you if youve ta...
# 3       i guess im just not good enough for anyone fuc...
# 4       i am struggling with the outcome of a court ma...
# ...                                                   ...
# 141995  i cannot suffer from an anxiety disorder when ...
# 141996  a question of mine about a question of mine th...
# 141997  welcome to this months personal accountability...
# 141998  agree that you should stop smoking weed usuall...
# 141999  catherine the duchess of cambridge doesnt look...
#
#                        label  encoded_labels
# 0                     stress              17
# 1              mentalillness               8
# 2       personality disorder              13
# 3                 depression               5
# 4                        bpd               4
# ...                      ...             ...
# 141995        panic_disorder              12
# 141996            offmychest              11
# 141997     hoarding disorder               7
# 141998        social anxiety              16
# 141999       eating disorder               6
#
# [142000 rows x 3 columns]

# %%
for index, class_name in enumerate(label_encoder.classes_):
    print(f"{class_name} --> {index}")
# Out:
# adhd --> 0
# anxiety --> 1
# bdd --> 2
# bipolar --> 3
# bpd --> 4
# depression --> 5
# eating disorder --> 6
# hoarding disorder --> 7
# mentalillness --> 8
# normal --> 9
# ocd --> 10
# offmychest --> 11
# panic_disorder --> 12
# personality disorder --> 13
# ptsd --> 14
# schizophrenia --> 15
# social anxiety --> 16
# stress --> 17
# suicidal --> 18

# %%
train_texts, test_texts, train_labels, test_labels = train_test_split(
    df["text"].tolist(), df["encoded_labels"].tolist(), test_size=0.2, random_state=42)

# %%
class CustomDebertaClassifier(nn.Module):
    def __init__(self, deberta_model, num_labels):
        super(CustomDebertaClassifier, self).__init__()
        self.deberta = deberta_model  # Pretrained DeBERTa model
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Linear(768, num_labels)  # 19 output classes
        self.criterion = nn.CrossEntropyLoss()  # ✅ Correct loss function

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.deberta(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.last_hidden_state[:, 0, :]  # CLS token representation
        pooled_output = self.dropout(pooled_output)
        logits = self.classifier(pooled_output)

        loss = None
        if labels is not None:
            loss = self.criterion(logits, labels)  # Compute loss only when labels are provided

        return {"loss": loss, "logits": logits}


deberta_model = AutoModel.from_pretrained("microsoft/deberta-v3-base")
model = CustomDebertaClassifier(deberta_model, num_labels=19)

tokenizer = AutoTokenizer.from_pretrained("microsoft/deberta-v3-base")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# C:\Users\amil\anaconda3\envs\tf_gpu\lib\site-packages\transformers\convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# CustomDebertaClassifier(
#   (deberta): DebertaV2Model(
#     (embeddings): DebertaV2Embeddings(
#       (word_embeddings): Embedding(128100, 768, padding_idx=0)
#       (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#       (dropout): StableDropout()
#     )
#     (encoder): DebertaV2Encoder(
#       (layer): ModuleList(
#         (0-11): 12 x DebertaV2Layer(
#           (attention): DebertaV2Attention(
#             (self): DisentangledSelfAttention(
#               (query_proj): Linear(in_features=768, out_features=768, bias=True)
#               (key_proj): Linear(in_features=768, out_features=768, bias=True)
#               (value_proj): Linear(in_features=768, out_features=768, bias=True)
#               (pos_dropout): StableDropout()
#               (dropout): StableDropout()
#             )
#             (output): DebertaV2SelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaV2Intermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaV2Output(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#             (dropout): StableDropout()
#           )
#         )
#       )
#       (rel_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#     )
#   )
#   (dropout): Dropout(p=0.3, inplace=False)
#   (classifier): Linear(in_features=768, out_features=19, bias=True)
#   (criterion): CrossEntropyLoss()
# )

# %%
class MentalHealthDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=512):
        self.texts = texts
        self.labels = labels 
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = int(self.labels[idx]) 
        tokens = self.tokenizer(
            text, 
            padding="max_length",
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt"
        )
        return {
            "input_ids": tokens["input_ids"].squeeze(0),
            "attention_mask": tokens["attention_mask"].squeeze(0),
            "labels": torch.tensor(label, dtype=torch.long),  # Now label is int
        }

# %%
train_dataset = MentalHealthDataset(train_texts, train_labels, tokenizer)
test_dataset = MentalHealthDataset(test_texts, test_labels, tokenizer)
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=True)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Convert class labels to integer encoding
class_labels, y_encoded = np.unique(df['label'], return_inverse=True)

# Compute class weights (inverse of class frequency)
class_weights = compute_class_weight(class_weight="balanced", classes=np.arange(len(class_labels)), y=y_encoded)

# Convert to dictionary format (label → weight)
class_weights_dict = {label: weight for label, weight in zip(class_labels, class_weights)}

print("Class Weights:", class_weights_dict)
# Out:
# Class Weights: {'adhd': 0.9739736842105263, 'anxiety': 0.9739736842105263, 'bdd': 0.9739736842105263, 'bipolar': 0.9739736842105263, 'bpd': 0.9739736842105263, 'depression': 0.9739736842105263, 'eating disorder': 0.9739736842105263, 'hoarding disorder': 0.9866355065445143, 'mentalillness': 0.9739736842105263, 'normal': 0.9739736842105263, 'ocd': 0.9739736842105263, 'offmychest': 0.9739736842105263, 'panic_disorder': 0.9739736842105263, 'personality disorder': 0.9739736842105263, 'ptsd': 0.9739736842105263, 'schizophrenia': 0.9739736842105263, 'social anxiety': 1.3167737956879582, 'stress': 1.2508223684210527, 'suicidal': 0.9739736842105263}

# %%
optimizer = AdamW(model.parameters(), lr=2e-5)

num_training_steps = len(train_dataloader) * 3 
lr_scheduler = get_scheduler(
    name="linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=num_training_steps
)
class_weights_tensor = torch.tensor(list(class_weights_dict.values()), dtype=torch.float).to(device)
loss_fn = torch.nn.CrossEntropyLoss(weight=class_weights_tensor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 optimizer = AdamW(model.parameters(), lr=2e-5)
#       3 num_training_steps = len(train_dataloader) * 3
#       4 lr_scheduler = get_scheduler(
#       5     name="linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=num_training_steps
#       6 )
#
# NameError: name 'model' is not defined

# %%
import os
import torch
import numpy as np
from tqdm import tqdm  # For progress bar

# Create directory for saving models
save_dir = "saved_models"
os.makedirs(save_dir, exist_ok=True)

# Training parameters
epochs = 10  
patience = 3  # Early stopping patience
best_val_loss = float("inf")
early_stop_counter = 0
grad_clip = 1.0  # Clip gradients to prevent explosion

# Training loop
for epoch in range(epochs):
    model.train()
    total_train_loss = 0

    print(f"\n🔄 Epoch {epoch+1}/{epochs}")
    train_progress = tqdm(train_dataloader, desc="Training", leave=False)
    for batch in train_progress:
        batch = {k: v.to(device) for k, v in batch.items()}  # Move batch to device
        outputs = model(input_ids=batch["input_ids"], attention_mask=batch["attention_mask"], labels=batch["labels"])
        loss = outputs["loss"] 
        optimizer.zero_grad()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)  # Gradient clipping

        optimizer.step()
        lr_scheduler.step()

        total_train_loss += loss.item()
        train_progress.set_postfix(loss=loss.item())  # Update progress bar

    avg_train_loss = total_train_loss / len(train_dataloader)

    # Validation loop
    model.eval()
    total_val_loss = 0

    with torch.no_grad():
        val_progress = tqdm(test_dataloader, desc="Validating", leave=False)
        for batch in val_progress:
            batch = {k: v.to(device) for k, v in batch.items()}

            outputs = model(**batch)
            loss = outputs.loss
            total_val_loss += loss.item()

            val_progress.set_postfix(loss=loss.item())  # Update progress bar

    avg_val_loss = total_val_loss / len(test_dataloader)
    print(f"📊 Epoch {epoch+1}/{epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        early_stop_counter = 0  # Reset counter
        model.save_pretrained(save_dir)  
        tokenizer.save_pretrained(save_dir)
        print(f"✅ Model saved! Best Val Loss: {avg_val_loss:.4f}")
    else:
        early_stop_counter += 1
        print(f"⚠️ No improvement. Early stop: {early_stop_counter}/{patience}")
    if early_stop_counter >= patience:
        print("🚀 Early stopping triggered! Training stopped.")
        break  
print("🎉 Training complete!")
# Out:
# 🔄 Epoch 1/10
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[77], line 28
#      25 for batch in train_progress:
#      26     batch = {k: v.to(device) for k, v in batch.items()}  # Move batch to device
# ---> 28     outputs = model(**batch)
#      29     loss = outputs.loss
#      31     optimizer.zero_grad()
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[69], line 10, in CustomDebertaClassifier.forward(self, input_ids, attention_mask, labels)
#       9 def forward(self, input_ids, attention_mask, labels=None):
# ---> 10     outputs = self.deberta(input_ids=input_ids, attention_mask=attention_mask)
#      11     pooled_output = outputs.last_hidden_state[:, 0, :]  # CLS token representation
#      12     pooled_output = self.dropout(pooled_output)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\transformers\models\deberta_v2\modeling_deberta_v2.py:1063, in DebertaV2Model.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#    1053     token_type_ids = torch.zeros(input_shape, dtype=torch.long, device=device)
#    1055 embedding_output = self.embeddings(
#    1056     input_ids=input_ids,
#    1057     token_type_ids=token_type_ids,
#    (...)
#    1060     inputs_embeds=inputs_embeds,
#    1061 )
# -> 1063 encoder_outputs = self.encoder(
#    1064     embedding_output,
#    1065     attention_mask,
#    1066     output_hidden_states=True,
#    1067     output_attentions=output_attentions,
#    1068     return_dict=return_dict,
#    1069 )
#    1070 encoded_layers = encoder_outputs[1]
#    1072 if self.z_steps > 1:
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\transformers\models\deberta_v2\modeling_deberta_v2.py:507, in DebertaV2Encoder.forward(self, hidden_states, attention_mask, output_hidden_states, output_attentions, query_states, relative_pos, return_dict)
#     497     output_states = self._gradient_checkpointing_func(
#     498         layer_module.__call__,
#     499         next_kv,
#    (...)
#     504         output_attentions,
#     505     )
#     506 else:
# --> 507     output_states = layer_module(
#     508         next_kv,
#     509         attention_mask,
#     510         query_states=query_states,
#     511         relative_pos=relative_pos,
#     512         rel_embeddings=rel_embeddings,
#     513         output_attentions=output_attentions,
#     514     )
#     516 if output_attentions:
#     517     output_states, att_m = output_states
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\transformers\models\deberta_v2\modeling_deberta_v2.py:355, in DebertaV2Layer.forward(self, hidden_states, attention_mask, query_states, relative_pos, rel_embeddings, output_attentions)
#     346 def forward(
#     347     self,
#     348     hidden_states,
#    (...)
#     353     output_attentions=False,
#     354 ):
# --> 355     attention_output = self.attention(
#     356         hidden_states,
#     357         attention_mask,
#     358         output_attentions=output_attentions,
#     359         query_states=query_states,
#     360         relative_pos=relative_pos,
#     361         rel_embeddings=rel_embeddings,
#     362     )
#     363     if output_attentions:
#     364         attention_output, att_matrix = attention_output
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\transformers\models\deberta_v2\modeling_deberta_v2.py:286, in DebertaV2Attention.forward(self, hidden_states, attention_mask, output_attentions, query_states, relative_pos, rel_embeddings)
#     277 def forward(
#     278     self,
#     279     hidden_states,
#    (...)
#     284     rel_embeddings=None,
#     285 ):
# --> 286     self_output = self.self(
#     287         hidden_states,
#     288         attention_mask,
#     289         output_attentions,
#     290         query_states=query_states,
#     291         relative_pos=relative_pos,
#     292         rel_embeddings=rel_embeddings,
#     293     )
#     294     if output_attentions:
#     295         self_output, att_matrix = self_output
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\transformers\models\deberta_v2\modeling_deberta_v2.py:714, in DisentangledSelfAttention.forward(self, hidden_states, attention_mask, output_attentions, query_states, relative_pos, rel_embeddings)
#     712 if self.relative_attention:
#     713     rel_embeddings = self.pos_dropout(rel_embeddings)
# --> 714     rel_att = self.disentangled_attention_bias(
#     715         query_layer, key_layer, relative_pos, rel_embeddings, scale_factor
#     716     )
#     718 if rel_att is not None:
#     719     attention_scores = attention_scores + rel_att
#
# File ~\anaconda3\envs\tf_gpu\lib\site-packages\transformers\models\deberta_v2\modeling_deberta_v2.py:810, in DisentangledSelfAttention.disentangled_attention_bias(self, query_layer, key_layer, relative_pos, rel_embeddings, scale_factor)
#     807 else:
#     808     r_pos = relative_pos
# --> 810 p2c_pos = torch.clamp(-r_pos + att_span, 0, att_span * 2 - 1)
#     811 p2c_att = torch.bmm(key_layer, pos_query_layer.transpose(-1, -2))
#     812 p2c_att = torch.gather(
#     813     p2c_att,
#     814     dim=-1,
#     815     index=p2c_pos.squeeze(0).expand([query_layer.size(0), key_layer.size(-2), key_layer.size(-2)]),
#     816 ).transpose(-1, -2)
#
# RuntimeError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
